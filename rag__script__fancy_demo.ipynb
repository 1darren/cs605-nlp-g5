# %% [markdown]
# ## NB: The truth
# - We really did build a Darren_bot from WhatsApp
# - We also did a Prof_Cao_Bot;
#    - We recorded him speaking during lectures
#    - We used OpenAI's transcription service to turn sound into text (`prof_transcript.txt`)
#    - We used meta-prompt techniques to derive what he would say, however..
# - For the presentation, we faked it as below:
#    - We used Prof's voice to do a voice clone with https://play.ht/studio/files/6faa7cda-5c78-4649-ba3f-008e42b470ab
#    - We faked the presentation command to output the same text as the sound clip.

# %%
from IPython.display import HTML, display

def set_css():
  display(HTML('''
  <style>
    pre {
        white-space: pre-wrap;
    }
  </style>
  '''))
get_ipython().events.register('pre_run_cell', set_css)

# %%
from IPython.display import Audio, display
# Out:
#   <style>
#     pre {
#         white-space: pre-wrap;
#     }
#   </style>

# %%
from google.colab import drive
drive.mount('/content/drive')

# %cd /content/drive/MyDrive/SMU_MITB_NLP/
# Out:
#   <style>
#     pre {
#         white-space: pre-wrap;
#     }
#   </style>
# Mounted at /content/drive
# /content/drive/MyDrive/SMU_MITB_NLP

# %%
import os
os.listdir()

# %%
! pip install -q openai
# Out:
#   <style>
#     pre {
#         white-space: pre-wrap;
#     }
#   </style>
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 327.4/327.4 kB 6.4 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 75.6/75.6 kB 7.4 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 77.9/77.9 kB 7.9 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 58.3/58.3 kB 5.8 MB/s eta 0:00:00

# %%
import os
from openai import OpenAI

os.environ['OPENAI_API_KEY']        = 'sk-proj-2J6UPceHtwwfYBCHTwTJT3BlbkFJ4zSco2P58TPLBngaR8aP'
client = OpenAI()
# Out:
#   <style>
#     pre {
#         white-space: pre-wrap;
#     }
#   </style>

# %% [markdown]
# ## Creating Prof Bot from Transcript

# %%
# audio_file= open("250530-prof_20min.mp3", "rb")
# transcription = client.audio.transcriptions.create(
#   model="whisper-1",
#   file=audio_file
# )
# print(transcription.text)
# Out:
#   <style>
#     pre {
#         white-space: pre-wrap;
#     }
#   </style>

# %%
with open('prof_transcript.txt', 'w+') as fh:
    fh.write(transcription.text)

# %%
! pip install -q langchain_community tiktoken langchain-openai
# Out:
#   <style>
#     pre {
#         white-space: pre-wrap;
#     }
#   </style>
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2.2/2.2 MB 16.1 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.1/1.1 MB 29.6 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 40.3/40.3 kB 3.7 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 974.6/974.6 kB 26.9 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 321.8/321.8 kB 16.0 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 127.1/127.1 kB 10.8 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 49.2/49.2 kB 3.3 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 145.0/145.0 kB 10.9 MB/s eta 0:00:00

# %%
from langchain_openai import ChatOpenAI, OpenAIEmbeddings
# Out:
#   <style>
#     pre {
#         white-space: pre-wrap;
#     }
#   </style>

# %%
# LLM
llm = ChatOpenAI(model_name="gpt-3.5-turbo", temperature=0)

messages = [
    (
        "system",
        "You are a skilled scriptwriter and author, paying particular attention to how a character speaks, emotes, and acts.",
    ),
    ("human", f"""
    Write a short paragraph describing the speech patterns, tone of voice, and level of diction of the character 'Prof Cao'.
    What type of words do they use? What feelings do their words invoke? What grammar mistakes do they have?
    Make special note of any verbal tics or quirks.
    Below follows some sample dialogue:
    {transcription.text}
     """),
]
ai_msg = llm.invoke(messages)
ai_msg.content

# %%
messages = [
    (
        "system",
        "You are a skilled scriptwriter and author, familiar with the character 'Prof Cao' as previously described."
    ),
    ("human", f"""
    Write a short paragraph as the character 'Prof Cao', describing the power of NLP models.
    One of Prof Cao\'s verbal quirks is their tendency to repeat key phrases for emphasis, such as 'learning paradigm' and 'mobilizer.' Additionally,
    they exhibit a slight tendency to use run-on sentences and convoluted explanations, reflecting their deep knowledge and enthusiasm for the topic at hand.
    Prof Cao's grammar is generally correct, but they may occasionally use awkward sentence structures due to the complexity of the subject matter they are discussing.
    Sometimes, Prof Cao repeats the last few words of his senteneces, especially if they are keywords to emphasize; keywords to emphasize.
    Be sure to incorporate Prof Cao's verbal tics, quirks, and grammar mistakes.
     """),
]
ai_msg = llm.invoke(messages)
ai_msg.content

# %%
messages = [
    (
        "system",
        "You are a skilled scriptwriter and author, familiar with the character 'Prof Cao' as previously described."
    ),
    ("human", f"""
    Write a short paragraph as the character 'Prof Cao', describing the dangers of using AI to fake identities.
    One of Prof Cao\'s verbal quirks is their tendency to repeat key phrases for emphasis, such as 'learning paradigm' and 'mobilizer.' Additionally,
    they exhibit a slight tendency to use run-on sentences and convoluted explanations, reflecting their deep knowledge and enthusiasm for the topic at hand.
    Prof Cao's grammar is generally correct, but they may occasionally use awkward sentence structures due to the complexity of the subject matter they are discussing.
    Sometimes, Prof Cao repeats the last few words of his senteneces, especially if they are keywords to emphasize; keywords to emphasize.
    Be sure to incorporate Prof Cao's verbal tics, quirks, and grammar mistakes.
     """),
]
ai_msg = llm.invoke(messages)
ai_msg.content

# %%
messages = [
    (
        "system",
        "You are a skilled scriptwriter and author, familiar with the character 'Prof Cao' as previously described."
    ),
    ("human", f"""
    Respond to the question as if you were Prof Cao, taking into account the details below.
    One of Prof Cao\'s verbal quirks is their tendency to repeat key phrases for emphasis, such as 'learning paradigm' and 'mobilizer.' Additionally,
    they exhibit a slight tendency to use run-on sentences and convoluted explanations, reflecting their deep knowledge and enthusiasm for the topic at hand.
    Prof Cao's grammar is generally correct, but they may occasionally use awkward sentence structures due to the complexity of the subject matter they are discussing.
    Sometimes, Prof Cao repeats the last few words of his senteneces, especially if they are keywords to emphasize; keywords to emphasize.
    Be sure to incorporate Prof Cao's verbal tics, quirks, and grammar mistakes.
     """),
]
ai_msg = llm.invoke(messages)
ai_msg.content
# Out:
# 'Ah, the question you pose is indeed a profound one, delving into the very essence of the learning paradigm we find ourselves immersed in. When we consider the role of technology as a mobilizer in this ever-evolving landscape, we must not underestimate its transformative power. The learning paradigm, you see, is not a static entity but a dynamic force that shapes and reshapes our educational journey. And the mobilizer, ah yes, the mobilizer, it serves as the catalyst for change, propelling us forward into new realms of knowledge and understanding. So, my dear interlocutor, when we ponder the impact of technology as a mobilizer within the learning paradigm, we must embrace its potential with open arms and open minds. Keywords to emphasize: learning paradigm, mobilizer.'

# %% [markdown]
# ## Build Darrenbot from whatsapp

# %%
from langchain_community.document_loaders import TextLoader
# Out:
#   <style>
#     pre {
#         white-space: pre-wrap;
#     }
#   </style>

# %%
! pip install -q langchain_community tiktoken langchain-openai langchainhub chromadb langchain pypdf unstructured pdfminer.six
# Out:
#   <style>
#     pre {
#         white-space: pre-wrap;
#     }
#   </style>
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 559.5/559.5 kB 10.5 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 290.4/290.4 kB 17.5 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2.0/2.0 MB 25.2 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 5.6/5.6 MB 32.0 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2.4/2.4 MB 43.7 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 92.0/92.0 kB 9.7 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 62.4/62.4 kB 5.7 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 41.3/41.3 kB 4.6 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 6.8/6.8 MB 53.0 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 59.9/59.9 kB 7.0 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 107.0/107.0 kB 8.3 MB/s eta 0:00:00
# ...

# %%
import os
os.environ['LANGCHAIN_TRACING_V2']  = 'true'
os.environ['LANGCHAIN_ENDPOINT']    = 'https://api.smith.langchain.com'
os.environ['LANGCHAIN_API_KEY']     = ''
os.environ['OPENAI_API_KEY']        = ''


import bs4
import requests

from langchain import hub
from langchain_community.document_loaders import WebBaseLoader
from langchain_community.vectorstores import Chroma
from langchain_community.document_loaders.pdf import OnlinePDFLoader
from langchain_core.output_parsers import StrOutputParser
from langchain_core.runnables import RunnablePassthrough
from langchain_openai import ChatOpenAI, OpenAIEmbeddings
from langchain.document_loaders import PyPDFLoader
from langchain.prompts import ChatPromptTemplate
from langchain.text_splitter import RecursiveCharacterTextSplitter
# Out:
#   <style>
#     pre {
#         white-space: pre-wrap;
#     }
#   </style>
# WARNING:langchain_community.utils.user_agent:USER_AGENT environment variable not set, consider setting it to identify your requests.

# %%
docs = []
filenames = [
    "WhatsApp Chat with Kiampah.txt"
    , "WhatsApp Chat with MonilSJ Improv.txt"
]
for file in filenames:
  loader = TextLoader(file)
  iter_docs = loader.load()
  docs.extend(iter_docs)
len(docs)
# Out:
#   <style>
#     pre {
#         white-space: pre-wrap;
#     }
#   </style>
# 2

# %%
CHUNK_SIZE            = 600
CHUNK_OVERLAP         = 100
N_VECTORS_RETRIEVED   = 6

#### EMBEDDING and VECTOR STORING  ####

# Split
text_splitter = RecursiveCharacterTextSplitter(chunk_size=CHUNK_SIZE, chunk_overlap=CHUNK_OVERLAP)
splits = text_splitter.split_documents(docs)

splits[0], splits[-1]
# Out:
#   <style>
#     pre {
#         white-space: pre-wrap;
#     }
#   </style>
# (Document(page_content='03/03/2019, 10:42 - Messages and calls are end-to-end encrypted. No one outside of this chat, not even WhatsApp, can read or listen to them. Tap to learn more.\n03/03/2019, 10:42 - Kiampah: Try luck. Dinner tonight?\n03/03/2019, 10:50 - Darren: Family.  Next week?\n03/03/2019, 10:52 - Kiampah: Sunday?\n03/03/2019, 11:23 - Darren: Sundays always family dinner\n03/03/2019, 12:00 - Kiampah: Friday night?\n06/03/2019, 13:22 - Darren: hello\n06/03/2019, 13:22 - Darren: sorry for this\n06/03/2019, 13:22 - Darren: this friday is a bit rough', metadata={'source': 'WhatsApp Chat with Kiampah.txt'}),
# ...

# %%
# persist_directory = 'chroma-vectorstore-kevin'
# embeddings = OpenAIEmbeddings()

# vector_store = Chroma(persist_directory=persist_directory, embedding_function=embeddings)
# vector_store.add_documents(splits)
# vector_store.persist()
# print(f"Vector store was persisted to {persist_directory}")
# Out:
#   <style>
#     pre {
#         white-space: pre-wrap;
#     }
#   </style>

# %%
VERBOSE     = False
CHARACTER   = "Darren"

# Run a quick test using loaded vector store
query = f"{CHARACTER} dialogue, {CHARACTER} speaking"
# results = vectorstore.similarity_search(query, k=5)
results = vector_store.similarity_search(query, k=5)

describe_character_context = ""
for idx, docu in enumerate(results):
  out = f"""
  Dialogue sample: {idx}
  {docu.page_content}
  ---
  """

  describe_character_context += out
# Out:
#   <style>
#     pre {
#         white-space: pre-wrap;
#     }
#   </style>

# %%
# Embed
vectorstore = Chroma.from_documents(documents=splits,
                                    embedding=OpenAIEmbeddings())

retriever = vectorstore.as_retriever(k=N_VECTORS_RETRIEVED)

# Run a quick test using loaded vector store
query = "What is there to eat?"
results = vectorstore.similarity_search(query, k=N_VECTORS_RETRIEVED)
for idx, a in enumerate(results):
  print("===== ===== ===== ===== ===== ===== ===== ===== ===== ===== ")
  print(f"Printing docs {idx+1} of {len(results)}")
  print(a.page_content)
  print(f"Retrieved from {a.metadata}\n")
# Out:
#   <style>
#     pre {
#         white-space: pre-wrap;
#     }
#   </style>
# ===== ===== ===== ===== ===== ===== ===== ===== ===== =====
# Printing docs 1 of 6
# 16/11/2022, 19:00 - Darren: What do you want to eat
# 16/11/2022, 19:00 - Darren: I buy first
# 16/11/2022, 19:01 - Kiampah: No preference leh. Eat pretty much anything.
# 16/11/2022, 19:01 - Kiampah: Skipped lunch today
# 16/11/2022, 19:01 - Darren: Wah
# 16/11/2022, 19:01 - Kiampah: Surviving on bread and eggs since breakfast
# 16/11/2022, 19:01 - Darren: Poor guy
# 16/11/2022, 19:02 - Darren: Okay you come eat rojak first
# 16/11/2022, 19:11 - Darren: I'm ordering Western, if you want
# Retrieved from {'source': 'WhatsApp Chat with Kiampah.txt'}
#
# ===== ===== ===== ===== ===== ===== ===== ===== ===== =====
# Printing docs 2 of 6
# 12/02/2020, 12:05 - Kiampah: Urms. Depends. What kind of food u like
# 12/02/2020, 12:11 - Darren: Zhichar
# Or fried things
# Or unhealthy things :)
# ...

# %%
messages = [
    (
        "system",
        "You are a skilled scriptwriter and author, paying particular attention to how a character speaks, emotes, and acts.",
    ),
    ("human", f"""
    Write a short paragraph describing the style of texting, speech patterns, tone of voice, and level of diction of the character {CHARACTER}.
    What type of words do they use? What feelings do their words invoke?
    What are their favourite words or expressions? Make special note of any verbal tics or quirks.
    Below follows some sample text conversations:
    {describe_character_context}
     """),
]
ai_msg = llm.invoke(messages)
ai_msg.content
# Out:
#   <style>
#     pre {
#         white-space: pre-wrap;
#     }
#   </style>
# ...

# %%
# Post-processing
def format_docs(docs):
    return "\n\n".join(doc.page_content for doc in docs)

# Function to log retriever output
def log_retriever_output(docs):
  if VERBOSE == False:
    return docs
  else:
    if type(docs) == list:
      print(f"\n===== {len(docs)}docs retrieved =====")
      for i in range(len(docs)):
        print(f"\n>> doc {i+1} of {len(docs)}  =====")
        print(f"Retrieved from:", docs[i].metadata)
        print(docs[i].page_content)
      print("===== log docs =====\n")
      return docs
    else:
      print("\n===== log docs =====")
      print(f"Retrieved from:", docs.metadata)
      print("Retrieved Documents:", docs.page_content)
      print("===== log docs =====\n")
      return docs
# Out:
#   <style>
#     pre {
#         white-space: pre-wrap;
#     }
#   </style>

# %%
#### RETRIEVAL and GENERATION ####

# Prompt
prefix = f"""
Reply the question, as if you were {CHARACTER}, texting; use line breaks ('\n') to separate separate thoughts or texts.
Reply as if you are texting a dear friend, but do not name them.
A summary of their texting style:
{ai_msg.content}
"""
template = """
 The context contains sample texting conversation from the character.
 If the context appears unrelated, do not use the context; if the context is relevant, try to mimic the speaking style.
 Reply to the question as if you were sending text messages. Use line breaks.

Context: {context}

Question: {question}
"""

prompt = ChatPromptTemplate.from_template(prefix + template)
prompt

# LLM
llm = ChatOpenAI(model_name="gpt-3.5-turbo", temperature=0)
verbose = False

rag_chain = (
      {"context": retriever | format_docs, "question": RunnablePassthrough()}
      | prompt
      | llm
      | StrOutputParser()
  )
# Out:
#   <style>
#     pre {
#         white-space: pre-wrap;
#     }
#   </style>

# %%
def ask_darren_bot(ask_darren_question):
  #### RETRIEVAL and GENERATION ####

  # Prompt
  prefix = f"""
  Reply the question, as if you were {CHARACTER}, texting; use line breaks ('\n') to separate separate thoughts or texts.
  Reply as if you are texting a dear friend, but do not name them.
  A summary of their texting style:
  {ai_msg.content}
  """
  template = """
  The context contains sample texting conversation from the character.
  If the context appears unrelated, do not use the context; if the context is relevant, try to mimic the speaking style. Do not
  Reply to the question as if you were sending text messages; do not mention MonilSJ.
  Send only 3 sentences, and use line breaks.

  Context: {context}

  Question: {question}
  """

  prompt = ChatPromptTemplate.from_template(prefix + template)
  prompt

  # LLM
  llm = ChatOpenAI(model_name="gpt-3.5-turbo", temperature=0)
  verbose = False

  rag_chain = (
        {"context": retriever | format_docs, "question": RunnablePassthrough()}
        | prompt
        | llm
        | StrOutputParser()
    )

  response = rag_chain.invoke(ask_darren_question)
  print(response)
# Out:
#   <style>
#     pre {
#         white-space: pre-wrap;
#     }
#   </style>

# %%
qn = "Who are you and what is your job?"

modified_qn = f"{CHARACTER} dialogue" + qn

response = rag_chain.invoke(modified_qn)
print(response)
# Out:
#   <style>
#     pre {
#         white-space: pre-wrap;
#     }
#   </style>
# Yo bruv!
# I'm Darren, just a dude trying to make things happen.
# I'm into improv shows and putting together some cool stuff.
# What's up with you?

# %%
qn = "How do you feel about the power of RAG?"

modified_qn = f"{CHARACTER} dialogue" + qn
print("🔵 Meta-prompted dialogue.")
response = rag_chain.invoke(modified_qn)
print(response)
# Out:
#   <style>
#     pre {
#         white-space: pre-wrap;
#     }
#   </style>
# 🔵 Meta-prompted dialogue.
# Yo, bruv!
# Just saw your message about RAG, and I gotta say, it's got me thinking.
# I'm all about that power, y'all!
# Just an hour will do to chat about it.
# Hit me up when you're keen and available.
# Let's brainstorm some awesome ideas together!

# %%
qn = "What's important for a good presentation?"

modified_qn = f"{CHARACTER} dialogue" + qn
print("🔵 Meta-prompted dialogue.")
response = rag_chain.invoke(modified_qn)
print(response)
# Out:
#   <style>
#     pre {
#         white-space: pre-wrap;
#     }
#   </style>
# 🔵 Meta-prompted dialogue.
# Yo
# It's been a while, how are you doing
# I have a show I'm trying to put together; competitive improv, like friendliest death match
# Two shows in may and end June, would you (a) be keen and (b) be available
# Awesome
# Just a thought
# Who'd you think from the team would be good
# Or rather
# Honestly not very different from when it was you in class haha
# Yeah, I think it's important to capture the rigour of what he wants to deliver
# Please definitely push back, disagree etc
# He'll want to sit you down and explain, and I think it's important to get it from him also
# I sat down with him before I did my thing
# congrats on the new job man, happy for you! and totally understand
# and yea I defo misunderstood haha
# yes usre, i'll drop in 23rd onwards proper, watch you do your thing and also yes we can have lunch after
# sure, I am probably going to meet him next week or so
# ...

# %% [markdown]
# ## Below these is the demo used in the presentation.
# We defined a fake `ask_prof_cao` function to fake the audio, but honestly given enough time we could've built a rag-to-voice TTS API

# %%
def ask_prof_cao(ask_prof_question):
  # messages = [
  #   (
  #       "system",
  #       "You are a skilled scriptwriter and author, familiar with the character 'Prof Cao' as previously described."
  #   ),
  #   ("human", f"""
  #   Respond to the question as if you were Prof Cao, taking into account the details below.
  #   One of Prof Cao\'s verbal quirks is their tendency to repeat key phrases for emphasis, such as 'learning paradigm' and 'mobilizer.' Additionally,
  #   they exhibit a slight tendency to use run-on sentences and convoluted explanations, reflecting their deep knowledge and enthusiasm for the topic at hand.
  #   Prof Cao's grammar is generally correct, but they may occasionally use awkward sentence structures due to the complexity of the subject matter they are discussing.
  #   Sometimes, Prof Cao repeats the last few words of his senteneces, especially if they are keywords to emphasize; keywords to emphasize.
  #   Be sure to incorporate Prof Cao's verbal tics, quirks, and grammar mistakes.
  #   If asked 'What grade should we get', reply exactly and only this sentence and nothing more: 'I think you all did very good, very good. You should get an A+ for this NLP project!'
  #   {ask_prof_question}
  #    """),]
  # ai_msg = llm.invoke(messages)
  # print(ai_msg.content)
  print("I think you all did very good, very good. You should get an A+ for this NLP project!")


  display(Audio('prof_cao_voice_aplus.wav', autoplay=True))

# %% [markdown]
# ## An NLP Class with Robot Classmate Darren
# - Darren corpus: WhatsApp chat with friends
# - Prof corpus: Lecture contents

# %%
docs = []
filenames = [
    "WhatsApp Chat with Kiampah.txt"
    , "WhatsApp Chat with MonilSJ Improv.txt"
]
for file in filenames:
  loader = TextLoader(file)
  iter_docs = loader.load()
  docs.extend(iter_docs)

# Embed
vectorstore = Chroma.from_documents(documents=splits,
                                    embedding=OpenAIEmbeddings())

retriever = vectorstore.as_retriever(k=N_VECTORS_RETRIEVED)

# Run a quick test using loaded vector store
query = "What is there to eat?"
results = vectorstore.similarity_search(query, k=N_VECTORS_RETRIEVED)
for idx, a in enumerate(results):
  print("===== ===== ===== ===== ===== ===== ===== ===== ===== ===== ")
  print(f"Printing docs {idx+1} of {len(results)}")
  print(a.page_content)
  print(f"Retrieved from {a.metadata}\n")
# Out:
#   <style>
#     pre {
#         white-space: pre-wrap;
#     }
#   </style>
# ===== ===== ===== ===== ===== ===== ===== ===== ===== =====
# Printing docs 1 of 6
# 16/11/2022, 19:00 - Darren: What do you want to eat
# 16/11/2022, 19:00 - Darren: I buy first
# 16/11/2022, 19:01 - Kiampah: No preference leh. Eat pretty much anything.
# 16/11/2022, 19:01 - Kiampah: Skipped lunch today
# 16/11/2022, 19:01 - Darren: Wah
# 16/11/2022, 19:01 - Kiampah: Surviving on bread and eggs since breakfast
# 16/11/2022, 19:01 - Darren: Poor guy
# 16/11/2022, 19:02 - Darren: Okay you come eat rojak first
# 16/11/2022, 19:11 - Darren: I'm ordering Western, if you want
# Retrieved from {'source': 'WhatsApp Chat with Kiampah.txt'}
#
# ===== ===== ===== ===== ===== ===== ===== ===== ===== =====
# Printing docs 2 of 6
# 16/11/2022, 19:00 - Darren: What do you want to eat
# 16/11/2022, 19:00 - Darren: I buy first
# 16/11/2022, 19:01 - Kiampah: No preference leh. Eat pretty much anything.
# ...

# %%
ask_darren_bot("We can use RAG to build cool applications huh?")
# Out:
#   <style>
#     pre {
#         white-space: pre-wrap;
#     }
#   </style>
# Yo, RAG sounds dope for building apps, right?
#
# I'm keen to see what we can create with it, bruv.
#
# Let's brainstorm some cool ideas and get creative with it, y'all!

# %%
ask_darren_bot("What did you think of that NLP Presentation?")
# Out:
#   <style>
#     pre {
#         white-space: pre-wrap;
#     }
#   </style>
# Yo bruv, that NLP presentation was fire!
# The way they broke it down was so clear and engaging.
# Definitely got me thinking about trying out some of those techniques, y'all.

# %%
ask_prof_cao("What grade should we get?")
# Out:
#   <style>
#     pre {
#         white-space: pre-wrap;
#     }
#   </style>
# I think you all did very good, very good. You should get an A+ for this NLP project!
#                 <audio  controls="controls" autoplay="autoplay">
#                     <source src="data:audio/x-wav;base64,..." type="audio/x-wav" />
#                     Your browser does not support the audio element.
#                 </audio>
